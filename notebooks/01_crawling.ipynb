# %% [markdown]
# # 01. Data Crawling
#
# This notebook demonstrates the **search logic and parameters** used to collect data from Twitter (X).
#
# > **Note:**
# > * The actual crawling was performed on **Google Colab**.
# > * For full installation and usage instructions of the crawler, please refer to the official [tweet-harvest documentation](https://github.com/helmisatria/tweet-harvest).
# > * The code below acts as a **logical representation** of the process.
#
# ### 🔍 Search Query Parameters:
# | Parameter | Value | Description |
# | :--- | :--- | :--- |
# | **Keyword** | `tiktok shop` | Primary search term. |
# | **Period** | `2023-12-12` to `2024-01-12` | 1 month observation. |
# | **Filters** | `lang:id`, `-links`, `-replies` | Focus on Indonesian original tweets. |

# %%
filename = "ReopenTikTokShop.csv"
twitter_auth_token = "PASTE_YOUR_TWITTER_AUTH_TOKEN_HERE"  # Replace with your actual token

search_keyword = (
    "tiktok shop "
    "until:2024-01-12 "
    "since:2023-12-12 "
    "lang:id "
    "-filter:links "
    "-filter:replies"
)

limit = 20000

# %%
# !npx tweet-harvest@latest \
  -o "{filename}" \
  -s "{search_keyword}" \
  -l {limit} \
  --token "{twitter_auth_token}"
